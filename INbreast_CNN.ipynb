# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import keras

import cv2
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
img_size = 256
batch_size = 12
channel = 3

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory("/content/drive/MyDrive/INBreastCancer/IMAGE_CLASS",
                                                             shuffle= True,
                                                             seed = 42,
                                                             image_size=(img_size,img_size),
                                                             batch_size= batch_size,
                                                              color_mode = "rgb")
# Out:
# Found 410 files belonging to 3 classes.

# %%
class_name = dataset.class_names
class_name
# Out:
# ['Benign', 'Malignant', 'Normal']

# %%
for img_batch, label_batch in dataset.take(1):
    plt.imshow(img_batch[1].numpy().astype("uint8"))
    plt.title(class_name[label_batch[1]])
    plt.axis("Off")

# %%
print("Number of batches in a Dataset:", len(dataset))

# Taking 80% of data for training purpose
train_ds = dataset.take(round(len(dataset)* 0.8))

# Skipping 80% of training data and Taking remaining 20% of data for Validation and Test
val_n_test = dataset.skip(round(len(dataset)*0.8))

# Taking 10% of data from val_n_test for validation and another 10% for test data
val_ds = val_n_test.take(round(len(val_n_test)*0.5))
test_ds = val_n_test.skip(round(len(val_n_test)*0.5))

print("Train Dataset:",len(train_ds))
print()
print("Number of batches selected for test and validation:", len(val_n_test))
print("Validation Dataset:",len(val_ds))
print("Test Dataset:", len(test_ds))
# Out:
# Number of batches in a Dataset: 35
# Train Dataset: 28
#
# Number of batches selected for test and validation: 7
# Validation Dataset: 4
# Test Dataset: 3

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size= tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size= tf.data.AUTOTUNE)
val_ds  = val_ds.cache().shuffle(1000).prefetch(buffer_size= tf.data.AUTOTUNE)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_size,img_size, channel)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation('sigmoid'))

model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  activation (Activation)     (None, 254, 254, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  activation_1 (Activation)   (None, 125, 125, 32)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  activation_2 (Activation)   (None, 60, 60, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dense (Dense)               (None, 64)                3686464
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
#  activation_4 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 3,715,299
# Trainable params: 3,715,299
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_ds,
          batch_size = batch_size,
          validation_data = val_ds,
          verbose=1,
          epochs=20,
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 28/28 [==============================] - 27s 270ms/step - loss: 26.7377 - accuracy: 0.3601 - val_loss: 1.1460 - val_accuracy: 0.3958
# Epoch 2/20
# 28/28 [==============================] - 1s 24ms/step - loss: 1.1296 - accuracy: 0.5000 - val_loss: 1.0791 - val_accuracy: 0.4583
# Epoch 3/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.9919 - accuracy: 0.5089 - val_loss: 1.0305 - val_accuracy: 0.5625
# Epoch 4/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.8416 - accuracy: 0.6101 - val_loss: 1.0502 - val_accuracy: 0.5000
# Epoch 5/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.7208 - accuracy: 0.6726 - val_loss: 0.9995 - val_accuracy: 0.5417
# Epoch 6/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6723 - accuracy: 0.7173 - val_loss: 0.9683 - val_accuracy: 0.6875
# Epoch 7/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.5637 - accuracy: 0.7530 - val_loss: 0.8440 - val_accuracy: 0.6458
# Epoch 8/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.4851 - accuracy: 0.8125 - val_loss: 0.9749 - val_accuracy: 0.7083
# Epoch 9/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.4334 - accuracy: 0.8095 - val_loss: 1.0284 - val_accuracy: 0.6667
# Epoch 10/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.3619 - accuracy: 0.8363 - val_loss: 1.1868 - val_accuracy: 0.6667
# Epoch 11/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.3451 - accuracy: 0.8363 - val_loss: 1.2094 - val_accuracy: 0.6875
# Epoch 12/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.3027 - accuracy: 0.8750 - val_loss: 1.1088 - val_accuracy: 0.7083
# Epoch 13/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.2452 - accuracy: 0.8958 - val_loss: 1.3086 - val_accuracy: 0.7083
# Epoch 14/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.2682 - accuracy: 0.8899 - val_loss: 1.5274 - val_accuracy: 0.7083
# Epoch 15/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.1865 - accuracy: 0.9077 - val_loss: 1.5226 - val_accuracy: 0.6458
# Epoch 16/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.2055 - accuracy: 0.9167 - val_loss: 1.5611 - val_accuracy: 0.6458
# Epoch 17/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.1967 - accuracy: 0.9167 - val_loss: 1.7248 - val_accuracy: 0.6667
# Epoch 18/20
# 28/28 [==============================] - 1s 22ms/step - loss: 0.1987 - accuracy: 0.9167 - val_loss: 1.5018 - val_accuracy: 0.6667
# Epoch 19/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.1935 - accuracy: 0.9256 - val_loss: 1.5450 - val_accuracy: 0.6667
# Epoch 20/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.2040 - accuracy: 0.9256 - val_loss: 1.4876 - val_accuracy: 0.6250

# %%
scores = model.evaluate(test_ds)
# Out:
# 3/3 [==============================] - 6s 64ms/step - loss: 1.1397 - accuracy: 0.8462

# %%
scores
# Out:
# [1.139737606048584, 0.8461538553237915]

# %%
history.params
# Out:
# {'epochs': 20, 'steps': 28, 'verbose': 1}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
loss = history.history["loss"]
acc = history.history["accuracy"]

val_loss = history.history["val_loss"]
val_acc = history.history["val_accuracy"]

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.plot(range(20), acc, label="Accuracy")
plt.plot(range(20), val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")


plt.subplot(1,2,2)
plt.plot(range(20), loss, label="Loss")
plt.plot(range(20), val_loss,label="Validation_Loss")
plt.legend(loc="upper right")
plt.title("Loss and Validation Loss")
plt.show()

# %%
BATCH_SIZE = 6
plt.figure(figsize=(12, 12))
for images, labels in val_ds.take(1):
   for i in range(BATCH_SIZE):
      ax = plt.subplot(2, 3, i + 1)
      plt.imshow(images[i].numpy().astype('uint8'))
      actual_cls = class_name[labels[i]]
      prediction = model.predict(images)
      predicted_cls = class_name[np.argmax(prediction[i])]
      confidence = round(100 * (np.max(prediction[i])), 2)
      plt.title(f"Actual: {actual_cls},\n Predicted: {predicted_cls},\n Confidence Score: {confidence}%")
      plt.axis("off")

# %%
model.save("/content/drive/MyDrive/INBreastCancer/INbreastcancer_CNN.h5")

# %%
test_loss, test_acc = model.evaluate(test_ds, verbose=2)
print("\nTestAccuracy:", test_acc)
# Out:
# 3/3 - 0s - loss: 1.1397 - accuracy: 0.8462 - 47ms/epoch - 16ms/step
#
# TestAccuracy: 0.8461538553237915

# %%
new_model = keras.models.load_model("/content/drive/MyDrive/INBreastCancer/INbreastcancer_CNN.h5")

# %%
for img,label in test_ds.take(1):
  prediction = model.predict(img)
  print(class_name[np.argmax(prediction[0])])
  print(f"Accuracy Score: {round(np.max(prediction[0]),2)}")
  plt.imshow(img[0].numpy().astype("uint8"))
  plt.axis("off")
  break
# Out:
# Benign
# Accuracy Score: 1.0
